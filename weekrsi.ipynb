# %%
from numpy import mean
import math
import time
import ipywidgets as widgets
import json            
import urllib.request  
import urllib.parse
import re
import datetime
import finnhub
def rsi_func(a):
    
    t_epoch = time.time()
    
    
  
    now = int(t_epoch)
 
    #test value
    bfr = now - 8467200 
    ticker = a
    query = '?'
    apikey = 'c9nclciad3if6tl7i78g'
    link = 'https://finnhub.io/api/v1/stock/candle'
    params = urllib.parse.urlencode({'token':'c9nclciad3if6tl7i78g', 'symbol':ticker,'resolution':'W','from':bfr , 'to':now})
    t = (link + query + params)
    response_object = urllib.request.urlopen(t)
    response_string = response_object.read()
    response_as_dictionary = json.loads(response_string)
    change_in_price_list = []
    try:
        if mean(response_as_dictionary['v'])>2000:
            price_list = response_as_dictionary['c']
            i = 1
            j = 0
            gains = 0
            losses = 0
            print(len(price_list))
            while i <=14 and len(price_list)==15:
                change = price_list[i]-price_list[j]
                if change>0:
                    gains+=change
                else:
                    losses+=change

                change_in_price_list.append(change)

                i+=1
                j+=1
            if i == 15 and j == 14:
                avg_gain = gains/14
                avg_loss = (losses/14)*(-1)
                rs = avg_gain/avg_loss
                rsi = 100 - 100/(1+rs)

                print(f'{a} has rsi of {rsi}')
            else:
                 print('no data for ' + a)
        else:
            print("try again in a little")

    except KeyError:
        print('no data for ' + a)
# Out:
# 15
# SOXS has rsi of 41.9277108433735

# %%
mid_cap = ['NLY', 'GGB', 'AAL', 'DOCU', 'PLUG', 'CLF', 'SWN', 
           'NCLH', 'DXC', 'DKNG', 'CX', 'M', 'VIPS', 'X', 'LUMN', 
           'GPS', 'KGC', 'AUY', 'EDU', 'ALIT', 'BTU', 'FIVN', 'CHPT', 
           'AMC', 'BTG', 'AFRM', 'SOFI', 'GSAT', 'AEO', 'RIG', 'BB', 
           'JBLU', 'HBI', 'TLRY', 'ATUS']

mega_cap = ['AAPL', 'MSFT', 'TSLA', 'JNJ', 'JPM', 'XOM', 'V', 'WMT', 
            'TSM', 'NVDA', 'BAC', 'CVX', 'ABBV', 'PFE', 'MRK', 'KO', 
            'ORCL', 'BABA', 'CSCO', 'ABT', 
            'WFC', 'DIS', 'BMY', 'NKE', 'NEE', 'VZ', 'MS', 'COP', 
            'CMCSA', 'SCHW', 'T', 'C', 'INTC', 'AMD', 'BP', 'BA', 'NVAX','SOXS']

small_cap = ['LAUR', 'TELL', 'SPCE', 'SAVA', 'NVAX', 'FCEL', 'VEON', 'OPEN', 'UUUU', 'DNN', 'NGD', 
'NAT', 'MMAT', 'RIOT', 'SNDL', 'BNGO', 'SENS', 'WISH', 'INO', 'SKLZ', 'RIDE', 'OCGN', 'UP', 'GOTU', 
'SDC', 'ZOM', 'BBIG', 'VXRT', 'ASTR', 'HYSR', 'NAK', 'IDEX', 'ALZN', 'ROOT', 'WHEN', 'ATOS', 'ILUS', 
'SHIP', 'ATER', 'CIDM', 'CEI', 'BTBT', 'RCAT', 'RWLK', 'BMRA', 'ENG', 'TBLT', 'SRGA', 'SOS', 'ANY', 
'BTCM', 'TNXP', 'XELA', 'AIKI', 'TLSS', 'TTOO', 'FAMI', 'OLB', 'BRTX', 'SONN', 'HEMP', 'MCOA', 'GROM', 
'METX', 'ADXS', 'BIEI', 'AMNL', 'VGLS', 
'IDGC', 'GTCH', 'TGHI', 'OCLG', 'PUGE', 'SWRM', 'PASO', 'EVIO', 'MEDH', 'VDRM', 'GARB', 'NOHO']
print("!!!!!!!do not buy options on NEE!!!!!!!!")
print("!!!!!!!Short at 85+ and buy at 15 and below. This is minute by minute RSI so the moment you make a gain, get out of position!!!!!!!")
for x in mega_cap:
    rsi_func(x)
# Out:
# !!!!!!!do not buy options on NEE!!!!!!!!
# !!!!!!!Short at 85+ and buy at 15 and below. This is minute by minute RSI so the moment you make a gain, get out of position!!!!!!!
# 15
# AAPL has rsi of 42.570382527458655
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-f4fd24025a6c> in <module>
#      46 print("!!!!!!!Short at 85+ and buy at 15 and below. This is minute by minute RSI so the moment you make a gain, get out of position!!!!!!!")
#      47 for x in mega_cap:
# ---> 48     rsi_func(x)
#
# <ipython-input-3-f35ad8cdbff1> in rsi_func(a)
#      25     params = urllib.parse.urlencode({'token':'c9nclciad3if6tl7i78g', 'symbol':ticker,'resolution':'W','from':bfr , 'to':now})
#      26     t = (link + query + params)
# ---> 27     response_object = urllib.request.urlopen(t)
#      28     response_string = response_object.read()
#      29     response_as_dictionary = json.loads(response_string)
#
# ~/opt/anaconda3/lib/python3.8/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# ~/opt/anaconda3/lib/python3.8/urllib/request.py in open(self, fullurl, data, timeout)
#     523
#     524         sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 525         response = self._open(req, data)
#     526
#     527         # post-process response
#
# ~/opt/anaconda3/lib/python3.8/urllib/request.py in _open(self, req, data)
#     540
#     541         protocol = req.type
# --> 542         result = self._call_chain(self.handle_open, protocol, protocol +
#     543                                   '_open', req)
#     544         if result:
#
# ~/opt/anaconda3/lib/python3.8/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     500         for handler in handlers:
#     501             func = getattr(handler, meth_name)
# --> 502             result = func(*args)
#     503             if result is not None:
#     504                 return result
#
# ~/opt/anaconda3/lib/python3.8/urllib/request.py in https_open(self, req)
#    1391
#    1392         def https_open(self, req):
# -> 1393             return self.do_open(http.client.HTTPSConnection, req,
#    1394                 context=self._context, check_hostname=self._check_hostname)
#    1395
#
# ~/opt/anaconda3/lib/python3.8/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1352             except OSError as err: # timeout error
#    1353                 raise URLError(err)
# -> 1354             r = h.getresponse()
#    1355         except:
#    1356             h.close()
#
# ~/opt/anaconda3/lib/python3.8/http/client.py in getresponse(self)
#    1345         try:
#    1346             try:
# -> 1347                 response.begin()
#    1348             except ConnectionError:
#    1349                 self.close()
#
# ~/opt/anaconda3/lib/python3.8/http/client.py in begin(self)
#     305         # read until we get a non-100 response
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#     309                 break
#
# ~/opt/anaconda3/lib/python3.8/http/client.py in _read_status(self)
#     266
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#     270             raise LineTooLong("status line")
#
# ~/opt/anaconda3/lib/python3.8/socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# ~/opt/anaconda3/lib/python3.8/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# ~/opt/anaconda3/lib/python3.8/ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
for x in mid_cap:
    rsi_func(x)
# Out:
# 15
# NLY has rsi of 39.13948646773074
# 15
# GGB has rsi of 65.53808948004837
# 15
# AAL has rsi of 56.800000000000004
# 15
# DOCU has rsi of 40.47756041426928
# 15
# PLUG has rsi of 27.35010402874977
# 15
# CLF has rsi of 48.040887574262165
# 15
# SWN has rsi of 38.375108038029396
# 15
# NCLH has rsi of 58.21382007822686
# 15
# DXC has rsi of 50.01344447432105
# 15
# DKNG has rsi of 47.478723185031015
# 15
# CX has rsi of 55.223029784808325
# 15
# M has rsi of 66.5400443178221
# 15
# VIPS has rsi of 60.22845275181724
# 15
# X has rsi of 61.71301446051169
# 15
# LUMN has rsi of 17.576187101346576
# 15
# GPS has rsi of 76.34896621280888
# 15
# KGC has rsi of 64.13223140495867
# 15
# AUY has rsi of 63.05418719211822
# 15
# EDU has rsi of 53.17595845019952
# 15
# ALIT has rsi of 56.27817128139086
# 15
# BTU has rsi of 60.794044665012414
# 15
# FIVN has rsi of 34.529593639575964
# 15
# CHPT has rsi of 37.57183908045977
# 15
# AMC has rsi of 39.44083874188716
# 15
# BTG has rsi of 54.24954792043399
# 15
# AFRM has rsi of 32.16663821068806
# 15
# SOFI has rsi of 38.03513559611121
# 15
# GSAT has rsi of 42.94478527607362
# 15
# AEO has rsi of 71.96779063915452
# 15
# RIG has rsi of 52.892561983471076
# 15
# BB has rsi of 38.52295409181636
# 15
# JBLU has rsi of 53.34796926454446
# 15
# HBI has rsi of 32.561728395061735
# 15
# TLRY has rsi of 57.6530612244898
# 15
# ATUS has rsi of 24.43890274314215

# %%
for x in small_cap:
    rsi_func(x)
# Out:
# 15
# LAUR has rsi of 43.435754189944134
# 15
# TELL has rsi of 29.646522234891677
# 15
# SPCE has rsi of 37.19211822660099
# 15
# SAVA has rsi of 60.3377022080529
# 15
# NVAX has rsi of 33.27005220692928
# 15
# FCEL has rsi of 37.91528110140784
# 15
# VEON has rsi of 66.9441816461684
# 15
# OPEN has rsi of 26.01994560290119
# 15
# UUUU has rsi of 42.8789113717708
# 15
# DNN has rsi of 40.31007751937984
# 15
# NGD has rsi of 67.08986806074185
# 15
# NAT has rsi of 64.71494607087828
# 15
# MMAT has rsi of 68.23505323505324
# 15
# RIOT has rsi of 38.95675140310333
# 15
# SNDL has rsi of 55.239815159080045
# 15
# BNGO has rsi of 47.257383966244724
# 15
# SENS has rsi of 16.000000000000014
# 15
# WISH has rsi of 29.68380614657211
# 15
# INO has rsi of 41.06548279689234
# 15
# SKLZ has rsi of 37.275449101796404
# 15
# RIDE has rsi of 37.5018029712967
# 15
# OCGN has rsi of 26.277372262773724
# 15
# UP has rsi of 36.53395784543326
# 15
# GOTU has rsi of 46.014745441865095
# 15
# SDC has rsi of 19.126419087935346
# 15
# ZOM has rsi of 39.617666446934734
# 15
# BBIG has rsi of 30.213644088370955
# 15
# VXRT has rsi of 14.829659318637283
# 15
# ASTR has rsi of 24.62962962962962
# 15
# HYSR has rsi of 52.691218130311604
# 15
# NAK has rsi of 40.67013287117273
# 15
# IDEX has rsi of 12.416935636984988
# 15
# ALZN has rsi of 55.246913580246925
# 15
# ROOT has rsi of 28.769657724329335
# 15
# WHEN has rsi of 50.0
# 15
# ATOS has rsi of 33.80403458213256
# 15
# ILUS has rsi of 58.06207418622256
# 15
# SHIP has rsi of 46.76715589051964
# 15
# ATER has rsi of 22.88226848528356
# 15
# CIDM has rsi of 45.904673762147155
# 15
# CEI has rsi of 15.335560279380502
# 15
# BTBT has rsi of 23.87085694659112
# 15
# RCAT has rsi of 18.592964824120614
# 15
# RWLK has rsi of 44.08602150537634
# 15
# BMRA has rsi of 57.062146892655356
# 15
# ENG has rsi of 23.04359848833994
# 15
# TBLT has rsi of 43.40537627971022
# 15
# SRGA has rsi of 27.186761229314428
# 15
# SOS has rsi of 34.470291613148746
# 15
# ANY has rsi of 22.214336408800563
# 15
# BTCM has rsi of 26.623794212218655
# 15
# TNXP has rsi of 9.715639810426552
# 15
# XELA has rsi of 10.757758526154191
# 15
# AIKI has rsi of 26.050420168067234
# 15
# TLSS has rsi of 25.862068965517253
# 15
# TTOO has rsi of 12.261580381471404
# 15
# FAMI has rsi of 18.84122069880584
# 15
# OLB has rsi of 21.43355597647293
# 15
# BRTX has rsi of 51.75633745096891
# 15
# SONN has rsi of 17.524152611757003
# 15
# HEMP has rsi of 41.66666666666667
# 15
# MCOA has rsi of 42.857142857142854
# 15
# GROM has rsi of 12.88460710573736
# 15
# METX has rsi of 12.79097672186225
# 15
# ADXS has rsi of 9.808612440191396
# 15
# BIEI has rsi of 55.555555555555564
# 15
# AMNL has rsi of 52.64650283553876
# 15
# VGLS has rsi of 33.22147651006712
# 15
# IDGC has rsi of 16.666666666666657
# 15
# GTCH has rsi of 10.526315789473685
# 15
# TGHI has rsi of 19.23076923076924
# 15
# OCLG has rsi of 38.095238095238095
# 15
# PUGE has rsi of 50.0
# 15
# SWRM has rsi of 35.18518518518519
# 15
# PASO has rsi of 50.0
# 15
# EVIO has rsi of 25.0
# 15
# MEDH has rsi of 55.55555555555556
# 15
# VDRM has rsi of 26.54867256637168
# 12
# no data for GARB
# 15
# NOHO has rsi of 33.27759197324414
