# %%
from numpy import mean
import math
import time
import ipywidgets as widgets
import json            
import urllib.request  
import urllib.parse
import re
import datetime
import finnhub
def rsi_func(a):
    
    t_epoch = time.time()
    
    
  
    now = int(t_epoch)
 
    #test value
    bfr = now - 4500
    ticker = a
    query = '?'
    apikey = 'c9nclciad3if6tl7i78g'
    link = 'https://finnhub.io/api/v1/stock/candle'
    params = urllib.parse.urlencode({'token':'c9nclciad3if6tl7i78g', 'symbol':ticker,'resolution':5,'from':bfr , 'to':now})
    t = (link + query + params)
    response_object = urllib.request.urlopen(t)
    response_string = response_object.read()
    response_as_dictionary = json.loads(response_string)
    change_in_price_list = []
    try:
        if mean(response_as_dictionary['v'])>2000:
            price_list = response_as_dictionary['c']
            i = 1
            j = 0
            gains = 0
            losses = 0
            print(len(price_list))
            while i <=14 and len(price_list)==15:
                change = price_list[i]-price_list[j]
                if change>0:
                    gains+=change
                else:
                    losses+=change

                change_in_price_list.append(change)

                i+=1
                j+=1
            if i == 15 and j == 14:
                avg_gain = gains/14
                avg_loss = (losses/14)*(-1)
                rs = avg_gain/avg_loss
                rsi = 100 - 100/(1+rs)

                print(f'{a} has rsi of {rsi}')
            else:
                 print('no data for ' + a)
        else:
            print("Wait then try again")

    except KeyError:
        print('no data for ' + a)
# Out:
# 15
# PFE has rsi of 95.1923076923067
# 15
# BAC has rsi of 24.383466481416733
# 15
# T has rsi of 30.934205743366462
# 15
# TSLA has rsi of 23.156743491250765

# %%
mega_cap = ['AAPL', 'MSFT', 'TSLA', 'JNJ', 'JPM', 'XOM', 'V', 'WMT', 
            'TSM', 'NVDA', 'BAC', 'CVX', 'ABBV', 'PFE', 'MRK', 'KO', 
            'ORCL', 'BABA', 'CSCO', 'ABT', 
            'WFC', 'DIS', 'BMY', 'NKE', 'NEE', 'VZ', 'MS', 'COP', 
            'CMCSA', 'SCHW', 'T', 'C', 'INTC', 'AMD', 'BP', 'BA', 'NVAX','SOXS']
print("!!!!!!!do not buy options on NEE!!!!!!!!")
print("!!!!!!!Short at 85+ and buy at 15 and below. This is minute by minute RSI so the moment you make a gain, get out of position!!!!!!!")
for x in mega_cap:
    rsi_func(x)
# Out:
# !!!!!!!do not buy options on NEE!!!!!!!!
# !!!!!!!Short at 85+ and buy at 15 and below. This is minute by minute RSI so the moment you make a gain, get out of position!!!!!!!
# 15
# AAPL has rsi of 38.654962059217134
# 15
# MSFT has rsi of 53.180093729078315
# 15
# TSLA has rsi of 15.39297563207883
# 14
# no data for JNJ
# 14
# no data for JPM
# 14
# no data for XOM
# 14
# no data for V
# 14
# no data for WMT
# 14
# no data for TSM
# 15
# NVDA has rsi of 52.689135891000475
# 14
# no data for BAC
# 14
# no data for CVX
# 15
# ABBV has rsi of 55.666666666667204
# 14
# no data for PFE
# 14
# no data for MRK
# 14
# no data for KO
# 15
# ORCL has rsi of 56.98924731182875
# 15
# BABA has rsi of 50.429829650334916
# 15
# CSCO has rsi of 66.38655462184937
# 14
# no data for ABT
# 14
# no data for WFC
# 14
# no data for DIS
# 14
# no data for BMY
# 14
# no data for NKE
# 14
# no data for NEE
# 14
# no data for VZ
# 14
# no data for MS
# 14
# no data for COP
# 14
# no data for CMCSA
# 15
# SCHW has rsi of 28.927203065133853
# 14
# no data for T
# 14
# no data for C
# 15
# INTC has rsi of 50.35360678925028
# 14
# no data for AMD
# 14
# no data for BP
# 14
# no data for BA
# 15
# NVAX has rsi of 37.36533586818764
# 15
# SOXS has rsi of 52.875851694540344

# %%
mid_cap = ['NLY', 'GGB', 'AAL', 'DOCU', 'PLUG', 'CLF', 'SWN', 
           'NCLH', 'DXC', 'DKNG', 'CX', 'M', 'VIPS', 'X', 'LUMN', 
           'GPS', 'KGC', 'AUY', 'EDU', 'ALIT', 'BTU', 'FIVN', 'CHPT', 
           'AMC', 'BTG', 'AFRM', 'SOFI', 'GSAT', 'AEO', 'RIG', 'BB', 
           'JBLU', 'HBI', 'TLRY', 'ATUS']
for x in mega_cap:
    rsi_func(x)
